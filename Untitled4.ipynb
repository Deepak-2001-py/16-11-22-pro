# %%
import os
os.makedirs('/custom/assignment3')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_excel('/custom/assignment3/insurance.xlsx')
data
# Out:
#      age  sex     bmi  children  smoker  region      charges  insuranceclaim
# 0     19    0  27.900         0       1       3  16884.92400               1
# 1     18    1  33.770         1       0       2   1725.55230               1
# 2     28    1  33.000         3       0       2   4449.46200               0
# 3     33    1  22.705         0       0       1  21984.47061               0
# 4     32    1  28.880         0       0       1   3866.85520               1
# ..   ...  ...     ...       ...     ...     ...          ...             ...
# 96    28    0  37.620         1       0       2   3766.88380               0
# 97    54    0  30.800         3       0       3  12105.32000               0
# 98    55    1  38.280         0       0       2  10226.28420               1
# 99    56    1  19.950         0       1       0  22412.64850               1
# 100   38    1  19.300         0       1       3  15820.69900               1
#
# [101 rows x 8 columns]

# %%
data.isnull().sum()
# Out:
# age               0
# sex               0
# bmi               0
# children          0
# smoker            0
# region            0
# charges           2
# insuranceclaim    0
# dtype: int64

# %%
data.dropna()
# Out:
#      age  sex     bmi  children  smoker  region      charges  insuranceclaim
# 0     19    0  27.900         0       1       3  16884.92400               1
# 1     18    1  33.770         1       0       2   1725.55230               1
# 2     28    1  33.000         3       0       2   4449.46200               0
# 3     33    1  22.705         0       0       1  21984.47061               0
# 4     32    1  28.880         0       0       1   3866.85520               1
# ..   ...  ...     ...       ...     ...     ...          ...             ...
# 96    28    0  37.620         1       0       2   3766.88380               0
# 97    54    0  30.800         3       0       3  12105.32000               0
# 98    55    1  38.280         0       0       2  10226.28420               1
# 99    56    1  19.950         0       1       0  22412.64850               1
# 100   38    1  19.300         0       1       3  15820.69900               1
#
# [99 rows x 8 columns]

# %%
data.charges.fillna(data.charges.mean)
# Out:
# 0        16884.924
# 1        1725.5523
# 2         4449.462
# 3      21984.47061
# 4        3866.8552
#           ...
# 96       3766.8838
# 97        12105.32
# 98      10226.2842
# 99      22412.6485
# 100      15820.699
# Name: charges, Length: 101, dtype: object

# %%
data.charges.fillna(data.charges.mean).isnull().sum()
# Out:
# 0

# %%
data.charges.fillna(data.charges.median)
# Out:
# 0        16884.924
# 1        1725.5523
# 2         4449.462
# 3      21984.47061
# 4        3866.8552
#           ...
# 96       3766.8838
# 97        12105.32
# 98      10226.2842
# 99      22412.6485
# 100      15820.699
# Name: charges, Length: 101, dtype: object

# %%
data.charges.fillna(data.charges.median).isnull().sum()
# Out:
# 0

# %%
data.charges.isnull().sum()
# Out:
# 2

# %%
data.charges.fillna(data.charges.mode)
# Out:
# 0        16884.924
# 1        1725.5523
# 2         4449.462
# 3      21984.47061
# 4        3866.8552
#           ...
# 96       3766.8838
# 97        12105.32
# 98      10226.2842
# 99      22412.6485
# 100      15820.699
# Name: charges, Length: 101, dtype: object

# %%
data.charges.fillna(data.charges.mode).isnull().sum()
# Out:
# 0

# %%
data.charges=data.charges.fillna(data.charges.mean)

# %%
for i in range(len(data.age)):
  if data['age'][i]>60:
    data['age'][i]=50


data.tail()
# Out:
# <ipython-input-33-7c3fdeba9b12>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['age'][i]=50
#      age  sex    bmi  children  smoker  region     charges  insuranceclaim
# 96    28    0  37.62         1       0       2   3766.8838               0
# 97    54    0  30.80         3       0       3    12105.32               0
# 98    55    1  38.28         0       0       2  10226.2842               1
# 99    56    1  19.95         0       1       0  22412.6485               1
# 100   38    1  19.30         0       1       3   15820.699               1

# %%
data.drop_duplicates()
# Out:
#      age  sex     bmi  children  smoker  region      charges  insuranceclaim
# 0     19    0  27.900         0       1       3    16884.924               1
# 1     18    1  33.770         1       0       2    1725.5523               1
# 2     28    1  33.000         3       0       2     4449.462               0
# 3     33    1  22.705         0       0       1  21984.47061               0
# 4     32    1  28.880         0       0       1    3866.8552               1
# ..   ...  ...     ...       ...     ...     ...          ...             ...
# 96    28    0  37.620         1       0       2    3766.8838               0
# 97    54    0  30.800         3       0       3     12105.32               0
# 98    55    1  38.280         0       0       2   10226.2842               1
# 99    56    1  19.950         0       1       0   22412.6485               1
# 100   38    1  19.300         0       1       3    15820.699               1
#
# [100 rows x 8 columns]

# %%
data.corr()
# Out:
#                      age       sex       bmi  children    smoker    region  \
# age             1.000000 -0.125196  0.018572  0.044612  0.004662 -0.032271
# sex            -0.125196  1.000000 -0.054925 -0.037696  0.219385  0.080228
# bmi             0.018572 -0.054925  1.000000  0.036698  0.013822  0.121468
# children        0.044612 -0.037696  0.036698  1.000000 -0.079262 -0.012957
# smoker          0.004662  0.219385  0.013822 -0.079262  1.000000  0.228907
# region         -0.032271  0.080228  0.121468 -0.012957  0.228907  1.000000
# insuranceclaim  0.099552  0.078158  0.230812 -0.433757  0.433123  0.201042
#
#                 insuranceclaim
# age                   0.099552
# sex                   0.078158
# bmi                   0.230812
# children             -0.433757
# smoker                0.433123
# region                0.201042
# insuranceclaim        1.000000

# %%
plt.scatter(data['age'],data['bmi'])
plt.title('age Vs bmi scatter plot')
plt.xlabel('age')
plt.ylabel('bmi')
# Out:
# Text(0, 0.5, 'bmi')

# %%
plt.hist(data['age'])
plt.title(' age histogram plot ')
plt.xlabel('age')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')
